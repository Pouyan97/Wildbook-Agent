# %%
Key = "AIzaSyA958m4dOxRXF7o16bUF2-lzmR6lZowCBI"
# to install the required google api clients.
# !pip install --upgrade google-api-python-client
from Youtube import YouTube
import csv
yt = YouTube(Key)

# %%
snippet = yt.videos("J6JKpXsBWuk",True)

# %% [markdown]
# yt.videos returns title description and tags for the video as a list of tags. A new file will be made that has updated video descriptions and titles.

# %%
def makeIDList():
    lineCount = 0
    Vids = []
    with open('ytIds.csv', 'r') as csvfile:
        csv_reader = csv.reader(csvfile, delimiter=',')
        for row in csv_reader:
            if(lineCount == 0):
                pass
            else:
                Vids.append(row[0])
            lineCount += 1
    return Vids

# to create a file with ID and Desc, Title, Tags.
def createCSV(VidsList):
    if VidsList == []:
        return
    for vid in VidsList:
        with open('ytDirectLocationID.csv', 'w+') as csvfile:
            
            filewriter = csv.writer(csvfile, delimiter=',',
                        quoting=csv.QUOTE_MINIMAL)
            
            filewriter.writerow(['Video ID','Title', 'Description', 'tags'])
        #find the video
            YTVideo = yt.videos(vid,True)
#             print(YTVideo)

        #no video found..
            if not YTVideo:
#                 print(vid)
                filewriter.writerow([vid,'','',''])
                continue
        #get the snippet
            snippet = YTVideo[0]['snippet']
#             print(snippet)
#             print()

            # if an item is not specified do so.
            if 'tags' not in snippet.values():
                snippet['tags'] = ''
            if 'title' not in snippet.values():
                snippet['title'] = ''
            if 'description' not in snippet.values():
                snippet['description'] = ''
        #insert into the csv file
            filewriter.writerow([vid, snippet['title'],snippet['description'],snippet['tags']])
        #make a dictionary
            dic = {}
            dic.append([vid, snippet['title'],snippet['description'],snippet['tags']])

# %%
VidsList = []

VidsList = makeIDList()
# print(VidsList)
createCSV(VidsList)
# Out:
# [{'snippet': {'title': 'Whale Shark, Manta, Sharks, Turtles and more, snorkeling in Thudufushi (Maldives)', 'description': 'In this video you can see the Whale shark, Sharks, Manta, Stingray, Surgeonfish, Lion fish, Turtles, Rays fish and much more.\nFilmed with GoPro Hero 7 Black and GoPro Hero 4 Black.\n\nIn questo video potrete vedere lo squalo balena, diversi squali, tartarughe, pesci chirurgo, mante, trigone, aquile di mare e molto altro.\nFilmato con GoPro Hero 7 Black e GoPro hero 4 Black.', 'tags': ['Maldive', 'Thudufushi', 'Ari Atoll', 'Atollo di Ari', 'Whale shark', 'Squalo balena', 'Sharks', 'Squali', 'Murena', 'Moray', 'Stingray', 'Trigone', 'Aquila di mare', 'Rays fish', 'Pesce chirurgo', 'Surgeonfish', 'Lion fish', 'pesce leone', 'pesce scorpione', 'Tartarughe', 'turtles', 'manta', 'snorkeling', 'gopro hero 7 black', 'gopro hero 4 black']}}]
# ...

# %%
i = snippet[0]['snippet']
if 'yo' not in i.values():
    i['yo'] = ''
    print(i)
i = []
# Out:
# {'title': 'Whale Shark, Manta, Sharks, Turtles and more, snorkeling in Thudufushi (Maldives)', 'description': 'In this video you can see the Whale shark, Sharks, Manta, Stingray, Surgeonfish, Lion fish, Turtles, Rays fish and much more.\nFilmed with GoPro Hero 7 Black and GoPro Hero 4 Black.\n\nIn questo video potrete vedere lo squalo balena, diversi squali, tartarughe, pesci chirurgo, mante, trigone, aquile di mare e molto altro.\nFilmato con GoPro Hero 7 Black e GoPro hero 4 Black.', 'tags': ['Maldive', 'Thudufushi', 'Ari Atoll', 'Atollo di Ari', 'Whale shark', 'Squalo balena', 'Sharks', 'Squali', 'Murena', 'Moray', 'Stingray', 'Trigone', 'Aquila di mare', 'Rays fish', 'Pesce chirurgo', 'Surgeonfish', 'Lion fish', 'pesce leone', 'pesce scorpione', 'Tartarughe', 'turtles', 'manta', 'snorkeling', 'gopro hero 7 black', 'gopro hero 4 black'], 'yo': ''}
# to
# yo
# to
# yo
# to
# yo
# to
# yo
# to
# yo
# to
# yo
# to
# yo
# to
# yo
# to
# yo
# to
# yo
